# %%
import pandas as pd

df = pd.read_csv("data\credit_risk_loans.csv")
print(df.dtypes)
# Out:
# loan_id                     object
# application_id              object
# loan_product                object
# loan_purpose                object
# first_name                  object
# last_name                   object
# date_of_birth               object
# age                          int64
# gender                      object
# marital_status              object
# education_level             object
# employment_type             object
# annual_income                int64
# customer_since              object
# branch_code                 object
# branch_name                 object
# city                        object
# state                       object
# region                      object
# branch_type                 object
# credit_score                 int64
# credit_utilization_pct     float64
# debt_to_income_ratio       float64
# previous_defaults            int64
# existing_loan_count          int64
# existing_debt_amount       float64
# application_date            object
# ...

# %%
print("\n \n \n")
df = pd.read_csv("data\loan_payments.csv")
print(df.dtypes)
# Out:
#
#
#
# payment_id             object
# loan_id                object
# installment_number      int64
# due_date               object
# payment_date           object
# emi_amount            float64
# payment_amount        float64
# principal_paid        float64
# interest_paid         float64
# payment_status         object
# days_past_due           int64
# payment_mode           object
# remaining_balance     float64
# dtype: object
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\I Love My INDIA\AppData\Local\Temp\ipykernel_14560\3918687952.py:2: SyntaxWarning: invalid escape sequence '\l'
#   df = pd.read_csv("data\loan_payments.csv")
